# %%
import csv

# %%
def iterate_EMS_records(file_path):
    '''
    Retrieve each record from a CSV of EMS records from the filepath
    
    Intended for use with the WPRDC's record of EMS dispatches
    in Allegheny County and will provide a dictionary of each record
    for use by processing functions
    '''
    # Open file at filepath
    # Use for loop over each record
    # Output: A list of dictionaries
    global raw_data_ems
    with open(file_path) as file_s0:
        file = csv.DictReader(file_s0, delimiter=',')
        raw_data_ems_s0 = []
        for row in file:
            raw_data_ems_s0.append(row)
        raw_data_ems = raw_data_ems_s0

# %%
# Testing for funcation 'iterate_EMS_records(file_path)'

#iterate_EMS_records('raw_data/ac_ems_300records.csv')

# print(raw_data_ems)
# Out:
# [{'_id': '201', 'call_id_hash': '0035B925A96644EF52470A6C52D8AD', 'service': 'EMS', 'priority': 'E5', 'priority_desc': 'All administrative mark outs', 'call_quarter': 'Q1', 'call_year': '2016', 'description_short': 'NON EMERGENCY TRANSPORT', 'city_code': 'MCK', 'city_name': 'MCKEESPORT', 'geoid': '420035509001000', 'census_block_group_center__x': '-79.8466347248', 'census_block_group_center__y': '40.3492976745'}, {'_id': '202', 'call_id_hash': '0036F5CE96A3DF183E1D5E23ACBA2B', 'service': 'EMS', 'priority': 'E3', 'priority_desc': 'EMS Standard Basic Life Support response', 'call_quarter': 'Q1', 'call_year': '2019', 'description_short': 'SICK', 'city_code': 'BWB', 'city_name': 'BALDWIN BORO', 'geoid': '420034804004000', 'census_block_group_center__x': '-79.952111915', 'census_block_group_center__y': '40.3728513612'}, {'_id': '203', 'call_id_hash': '0037523BE5FBEDEB492A2838041580', 'service': 'EMS', 'priority': 'E3', 'priority_desc': 'EMS Standard Basic Life Support response', 'call_quarter': 'Q4', 'call_year': '2015', 'description_short': 'SICK', 'city_code': 'MCK', 'city_name': 'MCKEESPORT', 'geoid': '420035512001011', 'census_block_group_center__x': '-79.8383006323', 'census_block_group_center__y': '40.3497956349'}, {'_id': '204', 'call_id_hash': '0037865CA423B184C232DEB2DC0B54', 'service': 'EMS', 'priority': 'E2', 'priority_desc': 'EMS Standard Advanced Life Support response', 'call_quarter': 'Q3', 'call_year': '2019', 'description_short': 'SICK', 'city_code': 'PGH', 'city_name': 'PITTSBURGH', 'geoid': '420030201004009', 'census_block_group_center__x': '-79.9919828902', 'census_block_group_center__y': '40.4395626529'}, {'_id': '205', 'call_id_hash': '0037FC2A1D41F4C18D5BA6F58D1D78', 'service': 'EMS', 'priority': 'E5', 'priority_desc': 'All administrative mark outs', 'call_quarter': 'Q2', 'call_year': '2017', 'description_short': 'NON EMERGENCY TRANSPORT', 'city_code': 'MTL', 'city_name': 'MOUNT LEBANON', 'geoid': '420034736022000', 'census_block_group_center__x': '-80.0669711485', 'census_block_group_center__y': '40.3786157788'}, {'_id': '206', 'call_id_hash': '0038A6014DFC0858E246833EC7F26E', 'service': 'EMS', 'priority': 'E5', 'priority_desc': 'All administrative mark outs', 'call_quarter': 'Q3', 'call_year': '2019', 'description_short': 'NON EMERGENCY TRANSPORT', 'city_code': 'SEW', 'city_name': 'SEWICKLEY', 'geoid': '420034455001004', 'census_block_group_center__x': '-80.178012835', 'census_block_group_center__y': '40.5432389879'}, {'_id': '207', 'call_id_hash': '0038FEC29BFD3E42171F8A7A3A7C55', 'service': 'EMS', 'priority': 'E0', 'priority_desc': 'EMS Advanced Life Support life threatening response with Advanced Life Support backup', 'call_quarter': 'Q1', 'call_year': '2018', 'description_short': 'SICK', 'city_code': 'PGH', 'city_name': 'PITTSBURGH', 'geoid': '420030203001079', 'census_block_group_center__x': '-79.984805465', 'census_block_group_center__y': '40.4513590199'}, {'_id': '208', 'call_id_hash': '00392E2C9DE79D954D837C05301060', 'service': 'EMS', 'priority': 'E1', 'priority_desc': 'EMS Advanced Life Support life threatening response', 'call_quarter': 'Q1', 'call_year': '2017', 'description_short': 'BREATHING', 'city_code': 'CLA', 'city_name': 'CLAIRTON', 'geoid': '420034928002013', 'census_block_group_center__x': '-79.8811692823', 'census_block_group_center__y': '40.2925326785'}, {'_id': '209', 'call_id_hash': '0039E19E2DAD3A086636F478C0A47E', 'service': 'EMS', 'priority': 'E5', 'priority_desc': 'All administrative mark outs', 'call_quarter': 'Q3', 'call_year': '2018', 'description_short': 'DETAIL', 'city_code': 'PGH', 'city_name': 'PITTSBURGH', 'geoid': '420039812001014', 'census_block_group_center__x': '-80.0152721463', 'census_block_group_center__y': '40.4468558459'}, {'_id': '210', 'call_id_hash': '003A3F9DE94D4DF7ED8FC274A47D01', 'service': 'EMS', 'priority': 'E5', 'priority_desc': 'All administrative mark outs', 'call_quarter': 'Q4', 'call_year': '2019', 'description_short': 'NON EMERGENCY TRANSPORT', 'ci ...

# %%
def test_for_redacted_description(ems_rec):
    '''
    Examine EMS dispatch record and look for redacted or blank
    descriptions
    '''
    
    # Description must be spelled "description_short"
    # Output: A list of dictionaries of redacated accounts 
    global ems_redacted
    ems_redacted_s0 = []
    for record in ems_rec:
        if record['description_short'] == "Removed" or record['description_short'] == "":
            ems_redacted_s0.append(record)
    ems_redacted = ems_redacted_s0

# %%
# Testing for funcation 'test_for_redacted_description(ems_rec)'

# test_for_redacted_description(raw_data_ems)

# print(len(ems_redacted))
# Out:
# 51

# %%
def red_year_total(redaction_year):
    '''
    Maintains a dictionary of counts by year passed when called
    
    Assumes that each call corresponds with a single record
    in the EMS dispatch data set, so a call with input of '2019'
    means, add 1 to the 2019 total of redacted records
    '''
    
    global ems_red_year
    if str(redaction_year) in ems_red_year:
        year_value = ems_red_year[str(redaction_year)]
        year_value += 1
        total = ems_red_year['Total']
        total += 1
        ems_red_year.update({str(redaction_year): year_value, 'Total': total})
    else:
        year_value = 1
        total = ems_red_year['Total']
        total += 1
        ems_red_year.update({str(redaction_year): year_value, 'Total': total})

# %%
def red_year(data):
    '''
    
    '''
    
    global ems_red_year
    ems_red_year = {'Total':0}
    for record in data:
        red_year_total(record['call_year'])

# %%
# Testing for funcation 'red_year(data)'

red_year(ems_redacted)

print(sorted(ems_red_year.items()))
# Out:
# [('2015', 10), ('2016', 17), ('2017', 8), ('2018', 5), ('2019', 4), ('2020', 7), ('Total', 51)]

# %%
def write_redacted_rec_to_log(ems_rec):
    '''
    Extract record ID and write to log file specific in global dict
    '''

# %%
def display_redaction_count_by_year(year_counts):
    '''
    Given a dictionary of year(key):['total','redactions']
    make a pretty output to the console
    '''
