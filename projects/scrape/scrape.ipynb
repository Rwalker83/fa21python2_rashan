# %%
import urllib
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

# %%
url='https://fleet.linuxserver.io/'

# %%
page = urllib.request.urlopen(url)

# %%
print(page)

# %%
soup = BeautifulSoup(page, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>fleet</title>
# <link href="/assets/images/favicon-32x32.png" rel="shortcut icon" type="image/png"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <link href="https://fonts.googleapis.com/css?family=Pacifico|Nunito" rel="stylesheet"/>
# <link href="/assets/css/bulma-0.8.0.min.css" rel="stylesheet" type="text/css">
# <link href="/assets/css/app.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/css/fontawesome-all.min.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/css/prism.css" rel="stylesheet" type="text/css"/>
# </link></head>
# <body class="has-background-white has-text-grey-dark">
# <nav aria-label="main navigation" class="navbar is-normal-colour" id="MainNav" role="navigation">
# <div class="navbar-brand">
# <a class="navbar-item" href="/">
# <span class="title">fleet<span class="has-text-primary">.</span></span>
# </a>
# ...

# %%
test = soup.body
print(test)
# Out:
# <body class="has-background-white has-text-grey-dark">
# <nav aria-label="main navigation" class="navbar is-normal-colour" id="MainNav" role="navigation">
# <div class="navbar-brand">
# <a class="navbar-item" href="/">
# <span class="title">fleet<span class="has-text-primary">.</span></span>
# </a>
# <a aria-expanded="false" aria-label="menu" class="navbar-burger burger" data-target="navbarBasicExample" role="button">
# <span aria-hidden="true"></span>
# <span aria-hidden="true"></span>
# <span aria-hidden="true"></span>
# </a>
# </div>
# <div class="navbar-menu">
# <div class="navbar-end">
# <div class="navbar-item">
# <div class="field">
# <div class="control has-icons has-icons-left">
# <div class="select is-normal">
# <select id="RepositorySelection" name="RepositorySelection">
# <option selected="" value="10:linuxserver">linuxserver</option>
# <option value="13:lsiobase">lsiobase</option>
# <option value="14:lsiocommunity">lsiocommunity</option>
# </select>
# </div>
# ...

# %%
test2 = soup.find_all('tr', class_="image-row")
print(test2)
# Out:
# [<tr class="image-row" data-image-name="adguardhome-sync">
# <td class="is-vcentered has-text-right is-paddingless" style="width: 16px">
# <figure class="image is-16x16">
# <img alt="Title logo" src="/images/linuxserver_adguardhome-sync.png"/>
# </figure>
# </td>
# <td class="is-vcentered">
# <h4 class="title is-6">
# <a class="has-text-grey-dark" href="/image?name=linuxserver/adguardhome-sync">
# <span class="has-text-weight-light">linuxserver / </span><span class="has-text-weight-bold">adguardhome-sync</span>
# </a>
# </h4>
# </td>
# <td>
# </td>
# <td class="is-vcentered">
# <span class="tag is-light is-normal" title="Latest Version">
# <i class="fas fa-tag"></i> 0.3.2
#     </span>
# </td>
# <td class="is-vcentered has-text-small is-hidden-mobile">
#                 9,837
#             </td>
# <td class="is-vcentered has-text-small is-hidden-mobile">
#                 4
#             </td>
# <td class="is-vcentered has-text-small is-hidden-mobile">
# ...

# %%
print(soup.prettify().encode('utf-8'))
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n <head>\n  <title>\n   fleet\n  </title>\n  <link href="/assets/images/favicon-32x32.png" rel="shortcut icon" type="image/png"/>\n  <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>\n  <link href="https://fonts.googleapis.com/css?family=Pacifico|Nunito" rel="stylesheet"/>\n  <link href="/assets/css/bulma-0.8.0.min.css" rel="stylesheet" type="text/css">\n   <link href="/assets/css/app.css" rel="stylesheet" type="text/css"/>\n   <link href="/assets/css/fontawesome-all.min.css" rel="stylesheet" type="text/css"/>\n   <link href="/assets/css/prism.css" rel="stylesheet" type="text/css"/>\n  </link>\n </head>\n <body class="has-background-white has-text-grey-dark">\n  <nav aria-label="main navigation" class="navbar is-normal-colour" id="MainNav" role="navigation">\n   <div class="navbar-brand">\n    <a class="navbar-item" href="/">\n     <span class="title">\n      fleet\n      <span class="has-t
# ...

# %%
soup2 = BeautifulSoup(soup.prettify().encode('utf-8'), 'html.parser')

# %%
print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>
#    fleet
#   </title>
# <link href="/assets/images/favicon-32x32.png" rel="shortcut icon" type="image/png"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <link href="https://fonts.googleapis.com/css?family=Pacifico|Nunito" rel="stylesheet"/>
# <link href="/assets/css/bulma-0.8.0.min.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/css/app.css" rel="stylesheet" type="text/css">
# <link href="/assets/css/fontawesome-all.min.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/css/prism.css" rel="stylesheet" type="text/css"/>
# </link>
# </head>
# <body class="has-background-white has-text-grey-dark">
# <nav aria-label="main navigation" class="navbar is-normal-colour" id="MainNav" role="navigation">
# <div class="navbar-brand">
# <a class="navbar-item" href="/">
# <span class="title">
#       fleet
#       <span class="has-text-primary">
# ...

# %%
for item in test2:
    print(item.text)
# Out:
# linuxserver / adguardhome-sync
#
#
#
#
#
#
#
#  0.3.2
#
#
#
#                 9,837
#
#
#                 4
#
#
#                 18 Nov 2021 11:41:41
#
#
#
#
#
#
#
#
#
#
#
# linuxserver / airsonic
#
#
#
#
#
#
#
#  10.6.2
#
#
#
#                 65,438,527
#
#
#                 98
#
#
#                 02 Dec 2021 02:59:02
#
#
#
#
#
#
#
#
#
#
#
# linuxserver / apprise-api
#
#
#
#
#
#
#
#  0.7.0
#
#
#
#                 14,377
#
#
#                 4
#
#
#                 02 Dec 2021 03:01:21
#
#
#
#
#
#
#
#
#
# linuxserver / audacity
#
#
#
#
#
#
#
#  3.1.2
#
#
#
#                 4,285
#
#
#                 7
#
#
#                 29 Nov 2021 12:43:43
#
#
#
#
#
#
#
#
#
# linuxserver / babybuddy
#
#
#
#
#
#
#
#  1.9.2
#
#
#
#                 16,283
#
#
#                 3
#
#
#                 04 Dec 2021 13:22:46
#
#
#
#
#
#
#
#
#
#
#
# linuxserver / bazarr
#
#
#
#
#
#
#
#  version-v1.0.1
#
#
#
#                 401,698,695
#
#
#                 272
#
#
# ...

# %%
test2 = soup.find_all('tr', class_="image-row")
print(test2)
# Out:
# [<tr class="image-row" data-image-name="adguardhome-sync">
# <td class="is-vcentered has-text-right is-paddingless" style="width: 16px">
# <figure class="image is-16x16">
# <img alt="Title logo" src="/images/linuxserver_adguardhome-sync.png"/>
# </figure>
# </td>
# <td class="is-vcentered">
# <h4 class="title is-6">
# <a class="has-text-grey-dark" href="/image?name=linuxserver/adguardhome-sync">
# <span class="has-text-weight-light">linuxserver / </span><span class="has-text-weight-bold">adguardhome-sync</span>
# </a>
# </h4>
# </td>
# <td>
# </td>
# <td class="is-vcentered">
# <span class="tag is-light is-normal" title="Latest Version">
# <i class="fas fa-tag"></i> 0.3.2
#     </span>
# </td>
# <td class="is-vcentered has-text-small is-hidden-mobile">
#                 9,837
#             </td>
# <td class="is-vcentered has-text-small is-hidden-mobile">
#                 4
#             </td>
# <td class="is-vcentered has-text-small is-hidden-mobile">
# ...

# %%
test3 = pd.read_html('https://fleet.linuxserver.io/')

# %%
print(test3)
# Out:
# [     Unnamed: 0                            Name Unnamed: 2 Latest Version  \
# 0           NaN  linuxserver / adguardhome-sync        NaN          0.3.2
# 1           NaN          linuxserver / airsonic        NaN         10.6.2
# 2           NaN       linuxserver / apprise-api        NaN          0.7.0
# 3           NaN          linuxserver / audacity        NaN          3.1.2
# 4           NaN         linuxserver / babybuddy        NaN          1.9.2
# ..          ...                             ...        ...            ...
# 152         NaN         linuxserver / wireguard        NaN   1.0.20210914
# 153         NaN         linuxserver / wireshark        NaN          2.4.5
# 154         NaN         linuxserver / xbackbone        NaN          3.5.1
# 155         NaN                linuxserver / yq        NaN         2.13.0
# 156         NaN               linuxserver / znc        NaN          1.8.2
#
#         Pulls  Stars            Build Time
# ...
